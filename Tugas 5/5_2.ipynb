# %%
from urllib.parse import urljoin
from bs4 import BeautifulSoup
import requests

# %%
def get_soup(url):
    return BeautifulSoup(requests.get(url).text, 'html.parser')

# %%
def getGoPackage(msg, num):
    url = "https://pkg.go.dev/search?limit={}&m=package&q={}#more-results".format(num, msg)
    soup = get_soup(url)

    #Get value with beautifoulsoup in class SearchSnippet
    SearchSnippet = soup.find_all('div', class_='SearchSnippet')
    total = 1 
    for hasil in SearchSnippet:

        #Get p and a tag with beautifulsoup in class SearchSnippet
        p = hasil.find_all('p')

        if (p != []):    
            text = p[0].get_text().split(' ')
            text = text[12:]
            text = ' '.join(text)
        else:
            text ="Tidak ada"

        #Get text from a tag
        link = hasil.find_all('a')
        url_hasil_search = "https://pkg.go.dev" + link[0].get('href')
        
        print("Hasil {}\nkegunaan package: {}\nUrl: {}\n\n".format(total, text, url_hasil_search))
        total+=1

    return True

# %%
def getGoBlog(msg):
    url = "https://pkg.go.dev/search?q=" + msg
    soup = get_soup(url)

    #Get value with beautifoulsoup in class SearchSnippet
    SearchSnippet = soup.find_all('div', class_='SearchSnippet')

    #Get href with beautifulsoup in class SearchSnippet
    judul = SearchSnippet[0].find_all('a')
    url_hasil_search = "https://pkg.go.dev" + judul[0].get('href')
    soup = get_soup(url_hasil_search)

    #Get value with beautifoulsoup in class Documentation-indexList
    Documentation_indexList = soup.find_all('ul', class_='Documentation-indexList')

    #Get value li with beautifoulsoup
    Documentation_indexList_li = Documentation_indexList[0].find_all('a')

    # Get all text with beautifulsoup
    for i in Documentation_indexList_li:
        text = i.get_text().split(' ')
        if (text[0] == 'type'):
            print(i.get_text())
        elif (text[0] == 'func'):
            print('\t' + i.get_text())
    return True

# %%
def main():   
    getGoPackage("sort", 30)
    #getGoBlog("llrb+petar")
    
if __name__ == '__main__':
    main()
# Out:
# Hasil 1
# kegunaan package: Package sort provides primitives for sorting slices and user-defined collections.
#
# Url: https://pkg.go.dev/sort
#
#
# Hasil 2
# kegunaan package: Package sortorder implements sort orders and comparison functions.
#
# Url: https://pkg.go.dev/github.com/fvbommel/sortorder
#
#
# Hasil 3
# kegunaan package: Package collate contains types for comparing and sorting Unicode strings according to a given collation order.
#
# Url: https://pkg.go.dev/golang.org/x/text/collate
#
#
# Hasil 4
# kegunaan package: Tidak ada
# Url: https://pkg.go.dev/github.com/qor/sorting
#
#
# Hasil 5
# kegunaan package: Package xfast provides access to a sorted tree that treats integers as if they were words of m bits, where m can be 8, 16, 32, or 64.
#
# Url: https://pkg.go.dev/github.com/Workiva/go-datastructures/trie/xfast
#
#
# Hasil 6
# kegunaan package: Package sortutil provides utilities supplementing the standard 'sort' package.
#
# Url: https://pkg.go.dev/github.com/cznic/sortutil
#
#
# Hasil 7
# kegunaan package: Package table allows read and write sorted key/value.
#
# Url: https://pkg.go.dev/github.com/syndtr/goleveldb/leveldb/table
#
#
# Hasil 8
# kegunaan package: Package sorted provides a KeyValue interface and constructor registry.
#
# Url: https://pkg.go.dev/camlistore.org/pkg/sorted
#
#
# Hasil 9
# kegunaan package: Package txsort provides the transaction sorting according to BIP 69.
#
# Url: https://pkg.go.dev/github.com/btcsuite/btcutil/txsort
#
#
# Hasil 10
# kegunaan package: Package values is an internal package that defines methods such as sorting, comparison, and type conversion, that apply to interface types.
#
# Url: https://pkg.go.dev/github.com/osteele/liquid/values
#
#
# Hasil 11
# kegunaan package: Package villa contains some helper data structures: priority queue(interface{} and int as elements), slice wrapper(interface{}, int, float and complex as elements), Sort, binary search and merge with customized comparator.
#
# Url: https://pkg.go.dev/github.com/daviddengcn/go-villa
#
#
# Hasil 12
# kegunaan package: Package table allows read and write sorted key/value.
#
# Url: https://pkg.go.dev/github.com/pingcap/goleveldb/leveldb/table
#
#
# Hasil 13
# kegunaan package: Package sort provides primitives for sorting slices and user-defined collections.
#
# Url: https://pkg.go.dev/go4.org/sort
#
#
# Hasil 14
# kegunaan package: Tidak ada
# Url: https://pkg.go.dev/github.com/stevenle/topsort
#
#
# Hasil 15
# kegunaan package: Package cmpbin provides binary serialization routines which ensure that the serialized objects maintain the same sort order of the original inputs when sorted bytewise (i.e.
#
# Url: https://pkg.go.dev/go.chromium.org/luci/common/data/cmpbin
#
#
# Hasil 16
# kegunaan package: Tidak ada
# Url: https://pkg.go.dev/code.cloudfoundry.org/cli/util/sorting
#
#
# Hasil 17
# kegunaan package: Package sortp is a plus to the standard "sort" package.
#
# Url: https://pkg.go.dev/github.com/golangplus/sort
#
#
# Hasil 18
# kegunaan package: Package txsort provides the transaction sorting according to BIP 69.
#
# Url: https://pkg.go.dev/github.com/roasbeef/btcutil/txsort
#
#
# Hasil 19
# kegunaan package: Tidak ada
# Url: https://pkg.go.dev/github.com/juju/naturalsort
#
#
# Hasil 20
# kegunaan package: Sortutil is a Go library which lets you sort a slice without implementing a sort.Interface, and in different orderings: ascending, descending, or case-insensitive ascending or descending (for slices of strings.) Additionally, Sortutil lets you sort a slice of a custom struct by a given struct field or index--for example, you can sort a []MyStruct by the structs' "Name" fields, or a [][]int by the second index of each nested slice, similar to using sorted(key=operator.itemgetter/attrgetter) in Python.
#
# Url: https://pkg.go.dev/github.com/pmylund/sortutil
#
#
# Hasil 21
# kegunaan package: Package verstr supports comparing and sorting of version strings.
#
# Url: https://pkg.go.dev/github.com/Cloud-Foundations/Dominator/lib/verstr
#
#
# Hasil 22
# kegunaan package: Package sort provides implementations of parallel sorting algorithms.
#
# Url: https://pkg.go.dev/github.com/exascience/pargo/sort
#
#
# Hasil 23
# kegunaan package: Package sortutil provides utilities supplementing the standard 'sort' package.
#
# Url: https://pkg.go.dev/modernc.org/sortutil
#
#
# Hasil 24
# kegunaan package: Package sorted contains sort related utilities.
#
# Url: https://pkg.go.dev/github.com/yarpc/yab/sorted
#
#
# Hasil 25
# kegunaan package: Package sortedmap provides sorted maps implemented as either a Left-Leaning Red-Black Tree (in memory) or a B+Tree (pageable)
#
# Url: https://pkg.go.dev/github.com/NVIDIA/sortedmap
#
#
# Hasil 26
# kegunaan package: Package morass implements file system-backed sorting.
#
# Url: https://pkg.go.dev/github.com/biogo/biogo/morass
#
#
# Hasil 27
# kegunaan package: Package sortutil contains common sorting definitions and utilities for sorting data.
#
# Url: https://pkg.go.dev/devt.de/krotik/common/sortutil
#
#
# Hasil 28
# kegunaan package: Tidak ada
# Url: https://pkg.go.dev/github.com/dubbogo/gost/sort
#
#
# Hasil 29
# kegunaan package: Package conveyor provides an abstraction for message queues, brokers, buses and the sort.
#
# Url: https://pkg.go.dev/github.com/leolara/conveyor
#
#
# Hasil 30
# kegunaan package: Package betterguid generates 20-character guid (globally unique id) strings with good properties: They're 20 character strings, safe for inclusion in urls (don't require escaping) They're based on timestamp so that they sort **after** any existing ids They contain 72-bits of random data after the timestamp so that IDs won't collide with other clients' IDs They sort **lexicographically** (so the timestamp is converted to characters that will sort properly) They're monotonically increasing.
#
# Url: https://pkg.go.dev/github.com/kjk/betterguid
